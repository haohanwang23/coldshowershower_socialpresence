# %%
import cvxEDA

# %%
yn = (y - y.mean()) / y.std()
Fs = 25.
[r, p, t, l, d, e, obj] = cvxEDA.cvxEDA(yn, 1./Fs)
import pylab as pl
tm = pl.arange(1., len(y)+1.) / Fs
pl.hold(True)
pl.plot(tm, yn)
pl.plot(tm, r)
pl.plot(tm, p)
pl.plot(tm, t)
pl.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f74cead5e3e1> in <module>()
# ----> 1 yn = (y - y.mean()) / y.std()
#       2 Fs = 25.
#       3 [r, p, t, l, d, e, obj] = cvxEDA.cvxEDA(yn, 1./Fs)
#       4 import pylab as pl
#       5 tm = pl.arange(1., len(y)+1.) / Fs
#
# NameError: name 'y' is not defined

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('EDAnumpy.csv')

# %%
np.asarray(df.iloc[:,0])
# Out:
# array([0.090947, 0.085823, 0.088385, ..., 0.279246, 0.386845, 0.418869])
